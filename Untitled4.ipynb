# %% [markdown]
# <a href="https://colab.research.google.com/github/souzznv/atividades-python/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lista 03- Questão #04

# %%
print("Digite 10 números inteiros:")
lista_original = []
for i in range(10):
    numero = int(input(f"Digite o {i+1}º número: "))
    lista_original.append(numero)

lista_pares = []
lista_impares = []


for numero in lista_original:
    if numero % 2 == 0:
        lista_pares.append(numero)
    else:
        lista_impares.append(numero)


print("\n--- RESULTADOS ---")
print(f"Lista Original: {lista_original}")
print(f"Lista de Pares:  {lista_pares}")
print(f"Lista de Ímpares: {lista_impares}")
# Out:
# Digite 10 números inteiros:
# Digite o 1º número: 0
# Digite o 2º número: 1
# Digite o 3º número: 2
# Digite o 4º número: 3
# Digite o 5º número: 4
# Digite o 6º número: 56
# Digite o 7º número: 65
# Digite o 8º número: 7
# Digite o 9º número: 8
# Digite o 10º número: 9
#
# --- RESULTADOS ---
# Lista Original: [0, 1, 2, 3, 4, 56, 65, 7, 8, 9]
# Lista de Pares:  [0, 2, 4, 56, 8]
# Lista de Ímpares: [1, 3, 65, 7, 9]

# %% [markdown]
# Questão #05

# %%
numeros = []


for i in range(8):
    n = int(input(f"Digite o {i+1}º número: "))
    numeros.append(n)


maior = numeros[0]
menor = numeros[0]
pos_maior = 0
pos_menor = 0


for i in range(1, len(numeros)):
    if numeros[i] > maior:
        maior = numeros[i]
        pos_maior = i
    if numeros[i] < menor:
        menor = numeros[i]
        pos_menor = i

print(f"\nLista digitada: {numeros}")
print(f"Maior valor: {maior} na posição {pos_maior} (primeira ocorrência)")
print(f"Menor valor: {menor} na posição {pos_menor} (primeira ocorrência)")
# Out:
# Digite o 1º número: 10
# Digite o 2º número: 2
# Digite o 3º número: 3
# Digite o 4º número: 8
# Digite o 5º número: 6
# Digite o 6º número: 9
# Digite o 7º número: 5
# Digite o 8º número: 11
#
# Lista digitada: [10, 2, 3, 8, 6, 9, 5, 11]
# Maior valor: 11 na posição 7 (primeira ocorrência)
# Menor valor: 2 na posição 1 (primeira orrência)

# %% [markdown]
# Questão #06

# %%
nomes = []

while True:
    nome = input("Digite um nome (ou FIM para encerrar): ").strip()

    if nome.upper() == "FIM":
        break



    ja_existe = False
    for n in nomes:
        if n.upper() == nome.upper():
            ja_existe = True
            break

    if not ja_existe and nome != "":
        nomes.append(nome)
    elif ja_existe:
        print(f"'{nome}' já está na lista, não foi adicionado.")

print("\n--- Resultado ---")
print(f"Lista final: {nomes}")
print(f"Quantidade de nomes diferentes: : {len(nomes)}")
# Out:
# Digite um nome (ou FIM para encerrar): Jose
# Digite um nome (ou FIM para encerrar): Arthur
# Digite um nome (ou FIM para encerrar): Jose
# 'Jose' já está na lista, não foi adicionado.
# Digite um nome (ou FIM para encerrar): Lucas
# Digite um nome (ou FIM para encerrar): FIM
#
# --- Resultado ---
# Lista final: ['Jose', 'Arthur', 'Lucas']
# Quantidade de nomes diferentes: : 3

# %% [markdown]
# Questão #07

# %%
dias = ("Domingo", "Segunda-feira", "Terça-feira", "Quarta-feira", "Quinta-feira", "Sexta", "Sabádo")

try:
    numero = int(input("Digite um número de 1 a 7: "))

    if 1 <= numero <= 7:

        print(f"O dia correspondente é: {dias[numero - 1]}")
    else:
        print("Opção inválida! Digite um número entre 1 e 7.")

except ValueError:
    print("Opção inválida! Você precisa digitar um número.")
# Out:
# Digite um número de 1 a 7: 5
# O dia correspondente é: Quinta-feira

# %% [markdown]
# Questão #08

# %%
numeros = []

for i in range(6):
    n = int(input(f"Digite o {i+1}º número: "))
    numeros.append(n)

tupla_numeros = tuple(numeros)

qtd_5 = tupla_numeros.count(5)

if qtd_5 > 0:
    pos_5 = tupla_numeros.index(5)
    pos_5_msg = f"posição {pos_5}"
else:
    pos_5_msg = "não apareceu"

pares = 0
for num in tupla_numeros:
    if num % 2 == 0:
        pares += 1

print("\n--- Resultado ---")
print(f"Tupla formada: {tupla_numeros}")
print(f"O número 5 apareceu {qtd_5} vez(es)")
print(f"Primeira ocorrência do 5: {pos_5_msg}")
print(f"Quantidade de valores pares: {pares}")
# Out:
# Digite o 1º número: 2
# Digite o 2º número: 7
# Digite o 3º número: 3
# Digite o 4º número: 4
# Digite o 5º número: 5
# Digite o 6º número: 6
#
# --- Resultado ---
# Tupla formada: (2, 7, 3, 4, 5, 6)
# O número 5 apareceu 1 vez(es)
# Primeira ocorrência do 5: posição 4
# Quantidade de valores pares: 3

# %% [markdown]
# Questão #09

# %%
aluno = {}
aluno['nome'] = input("Digite o nome do aluno: ")
aluno['turma'] = input("Digite a turma: ")
aluno['nota1'] = float(input("Digite a nota 1: "))
aluno['nota2'] = float(input("Digite a nota 2: "))

media = (aluno['nota1'] + aluno['nota2']) / 2
aluno['media'] = media
if media >= 7:
    aluno['situacao'] = "Aprovado"
elif media >= 5:
    aluno['situacao'] = "Recuperação"
else:
    aluno['situacao'] = "Reprovado"

print("\n--- Dados do Aluno ---")
for chave, valor in aluno.items():
    print(f"{chave}: {valor}")
# Out:
# Digite o nome do aluno: Joara
# Digite a turma: 104-C
# Digite a nota 1: 7
# Digite a nota 2: 6
#
# --- Dados do Aluno ---
# nome: Joara
# turma: 104-C
# nota1: 7.0
# nota2: 6.0
# media: 6.5
# situacao: Recuperação

# %% [markdown]
# Questão #10

# %%
produtos = {
    "arroz": 7.50,
    "feijão": 8.90,
    "macarrão": 4.20,
    "leite": 5.00,
    "pão": 6.50
}

print("Produtos cadastrados:", ", ".join(produtos.keys()))

busca = input("\nDigite o nome do produto que quer consultar: ").strip().lower()

if busca in produtos:
    print(f"O preço de '{busca}' é R$ {produtos[busca]:.2f}")
else:
    print(f"Produto '{busca}' não encontrado no cadastro.")
print("\n--- Tabela completa ---")
for nome, preco in produtos.items():
    print(f"{nome}: R$ {preco:.2f}")
# Out:
# Produtos cadastrados: arroz, feijão, macarrão, leite, pão
#
# Digite o nome do produto que quer consultar: Feijão
# O preço de 'feijão' é R$ 8.90
#
# --- Tabela completa ---
# arroz: R$ 7.50
# feijão: R$ 8.90
# macarrão: R$ 4.20
# leite: R$ 5.00
# pão: R$ 6.50

# %% [markdown]
# Questão #11

# %%
contagem = {}

for i in range(8):
    palavra = input(f"Digite a {i+1}ª palavra: ").strip().lower()

    if palavra in contagem:
        contagem[palavra] += 1
    else:
        contagem[palavra] = 1

print("\n--- Resultado ---")
for palavra, qtd in contagem.items():
    print(f"{palavra}: {qtd} vez(es)")

print(f"\nTotal de palavras diferentes: {len(contagem)}")
# Out:
# Digite a 1ª palavra: Feijão
# Digite a 2ª palavra: Feijão
# Digite a 3ª palavra: Arroz
# Digite a 4ª palavra: Macarrão
# Digite a 5ª palavra: Turma
# Digite a 6ª palavra: Pao
# Digite a 7ª palavra: Açúcar
# Digite a 8ª palavra: Lucas
#
# --- Resultado ---
# feijão: 2 vez(es)
# arroz: 1 vez(es)
# macarrão: 1 vez(es)
# turma: 1 vez(es)
# pao: 1 vez(es)
# açúcar: 1 vez(es)
# lucas: 1 vez(es)
#
# Total de palavras diferentes: 7

# %% [markdown]
# Questão #12

# %%
estoque = {
    "arroz": 50,
    "feijão": 30,
    "macarrão": 25,
    "leite": 40
}

def mostrar_estoque():
    print("\nEstoque atual:")
    for produto, qtd in estoque.items():
        print(f" {produto}: {qtd}")

mostrar_estoque()

while True:
    produto = input("\nProduto vendido (ou FIM para parar): ").strip().lower()

    if produto.upper() == "FIM":
        break

    if produto not in estoque:
        print(f"Problema: produto '{produto}' não cadastrado.")
        continue

    try:
        qtd = int(input(f"Quantidade de '{produto}' vendida: "))
    except ValueError:
        print("Problema: digite um número inteiro.")
        continue

    if qtd <= 0:
        print("Problema: quantidade deve ser maior que zero.")
    elif estoque[produto] < qtd:
        print(f"Problema: estoque insuficiente. Só temos {estoque[produto]} de '{produto}'.")
    else:
        estoque[produto] -= qtd
        print(f"Ok! Venda de {qtd} {produto} realizada.")

print("\n--- ESTOQUE FINAL ---")
mostrar_estoque()
# Out:
# Estoque atual:
#  arroz: 50
#  feijão: 30
#  macarrão: 25
#  leite: 40
#
# Produto vendido (ou FIM para parar): Arroz
# Quantidade de 'arroz' vendida: 30
# Ok! Venda de 30 arroz realizada.
#
# Produto vendido (ou FIM para parar): FI
# Problema: produto 'fi' não cadastrado.
#
# Produto vendido (ou FIM para parar): FIM
#
# --- ESTOQUE FINAL ---
#
# Estoque atual:
#  arroz: 20
#  feijão: 30
#  macarrão: 25
#  leite: 40

# %% [markdown]
# Questão #13

# %%
alunos = []

for i in range(5):
    print(f"\n--- Aluno {i+1} ---")
    nome = input("Nome: ")
    nota1 = float(input("Nota 1: "))
    nota2 = float(input("Nota 2: "))
    media = (nota1 + nota2) / 2

    alunos.append({
        "nome": nome,
        "nota1": nota1,
        "nota2": nota2,
        "media": media,
        "situacao": "Aprovado" if media >= 7 else "Recuperação" if media >= 5 else "Reprovado"
    })

print("\n--- BOLETIM ---")
for a in alunos:
    print(f"{a['nome']} - Média: {a['media']:.1f} - {a['situacao']}")
# Out:
# --- Aluno 1 ---
# Nome: Joara
# Nota 1: 7
# Nota 2: 6
#
# --- Aluno 2 ---
# Nome: Arthur
# Nota 1: 3
# Nota 2: 10
#
# --- Aluno 3 ---
# Nome: Lucas
# Nota 1: 3
# Nota 2: 3
#
# --- Aluno 4 ---
# Nome: Maria
# Nota 1: 2
# Nota 2: 10
#
# --- Aluno 5 ---
# Nome: Paula
# Nota 1: 3
# Nota 2: 10
#
# --- BOLETIM ---
# Joara - Média: 6.5 - Recuperação
# Arthur - Média: 6.5 - Recuperação
# Lucas - Média: 3.0 - Reprovado
# Maria - Média: 6.0 - Recuperação
# Paula - Média: 6.5 - Recuperação

# %% [markdown]
# Questão #14

# %%
produtos = []


print("--- Cadastro de Produtos ---")
for i in range(5):
    print(f"\nProduto {i+1}:")
    codigo = int(input("Código: "))
    nome = input("Nome: ").strip()
    preco = float(input("Preço: R$ "))

    produto = (codigo, nome, preco)
    produtos.append(produto)


print("\n--- Consulta ---")
busca = int(input("Digite o código do produto que deseja buscar: "))

encontrado = False
for produto in produtos:

    if produto[0] == busca:
        print(f"\nProduto encontrado!")
        print(f"Nome: {produto[1]}")
        print(f"Preço: R$ {produto[2]:.2f}")
        encontrado = True
        break

if not encontrado:
    print(f"Código {busca} não encontrado.")

# %% [markdown]
# Questão #15

# %%
estoque = []


print("--- CADASTRO DE ESTOQUE ---")
for i in range(5):
    print(f"\nItem {i+1}:")
    codigo = int(input("Código: "))
    nome = input("Nome: ")
    quantidade = int(input("Quantidade: "))
    preco = float(input("Preço unitário: R$ "))

    item = {
        "codigo": codigo,
        "nome": nome,
        "quantidade": quantidade,
        "preco": preco
    }
    estoque.append(item)


print("\n(a) --- TODOS OS ITENS ---")
for item in estoque:
    print(f"Cód: {item['codigo']} | {item['nome']} | Qtd: {item['quantidade']} | Preço: R$ {item['preco']:.2f}")


valor_total = 0
for item in estoque:
    valor_total += item['quantidade'] * item['preco']

print(f"\n(b) Valor total do estoque: R$ {valor_total:.2f}")


maior_item = estoque[0]
maior_valor = maior_item['quantidade'] * maior_item['preco']

for item in estoque:
    valor_item = item['quantidade'] * item['preco']
    if valor_item > maior_valor:
        maior_valor = valor_item
        maior_item = item

print(f"\n(c) Item de maior valor em estoque:")
print(f" {maior_item['nome']} (Cód: {maior_item['codigo']}) - {maior_item['quantidade']} x R$ {maior_item['preco']:.2f} = R$ {maior_valor:.2f}")


resumo = (len(estoque), valor_total)

print(f"\n(d) Tupla resumo: {resumo}")
print(f" -> Quantidade de itens cadastrados: {resumo[0]}")
print(f" -> Valor total do estoque: R$ {resumo[1]:.2f}")
# Out:
# --- CADASTRO DE ESTOQUE ---
#
# Item 1:
# Código: 10
# Nome: Maçã
# Quantidade: 4
# Preço unitário: R$ 10
#
# Item 2:
# Código: 7
# Nome: Maçã
# Quantidade: 2
# Preço unitário: R$ 10
#
# Item 3:
# Código: 8
# Nome: Uva
# Quantidade: 5
# Preço unitário: R$ 8
#
# Item 4:
# Código: 9
# Nome: Abacaxi
# Quantidade: 10
# Preço unitário: R$ 6
#
# Item 5:
# Código: 5
# Nome: Oleo
# Quantidade: 30
# Preço unitário: R$ 3
#
# (a) --- TODOS OS ITENS ---
# Cód: 10 | Maçã  | Qtd: 4 | Preço: R$ 10.00
# Cód: 7 | Maçã  | Qtd: 2 | Preço: R$ 10.00
# Cód: 8 | Uva | Qtd: 5 | Preço: R$ 8.00
# Cód: 9 | Abacaxi | Qtd: 10 | Preço: R$ 6.00
# Cód: 5 | Oleo | Qtd: 30 | Preço: R$ 3.00
#
# (b) Valor total do estoque: R$ 250.00
#
# (c) Item de maior valor em estoque:
#  Oleo (Cód: 5) - 30 x R$ 3.00 = R$ 90.00
#
# (d) Tupla resumo: (5, 250.0)
#  -> Quantidade de itens cadastrados: 5
#  -> Valor total do estoque: R$ 250.00
